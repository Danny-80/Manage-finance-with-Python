# %%
import pandas as pd
import numpy as np

# %%
listing = pd.read_csv('listings_clean.csv')

# %%
listing
# Out:
#      Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 0         A     NYSE     Agilent Technologies, Inc.       81.68  2.593470e+10
# 1        AA     NYSE              Alcoa Corporation       29.15  5.407810e+09
# 2      AABA   NASDAQ                    Altaba Inc.       75.39  4.278113e+10
# 3       AAC     NYSE             AAC Holdings, Inc.        2.16  5.314109e+07
# 4       AAL   NASDAQ  American Airlines Group, Inc.       34.02  1.527687e+10
# ...     ...      ...                            ...         ...           ...
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72  6.819191e+08
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79  2.147266e+09
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74  5.040782e+08
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85  1.653995e+08
# 6851   ZYXI   NASDAQ                    Zynex, Inc.        5.02  1.618349e+08
#
# ...

# %%
listing.head()
# Out:
#   Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68  2.593470e+10
# 1     AA     NYSE              Alcoa Corporation       29.15  5.407810e+09
# 2   AABA   NASDAQ                    Altaba Inc.       75.39  4.278113e+10
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16  5.314109e+07
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02  1.527687e+10
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
listing_2000 = listing.IPO_Year == 2000

# %%
listing_2000 = listing[listing_2000].head()

# %%
listing_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 57 to 660
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      5 non-null      object
#  1   Exchange    5 non-null      object
#  2   Name        5 non-null      object
#  3   Last_Price  5 non-null      float64
#  4   Market_Cap  5 non-null      float64
#  5   IPO_Year    5 non-null      int64
#  6   Sector      5 non-null      object
#  7   Industry    5 non-null      object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 360.0+ bytes

# %%
listing_2000_sector = (listing_2000.Sector == "Health Care")

# %%
listing_2000_sector
# Out:
# 57     False
# 144     True
# 457     True
# 465     True
# 660    False
# Name: Sector, dtype: bool

# %%
listing_2000.loc[listing_2000_sector]
# Out:
#     Symbol Exchange                         Name  Last_Price    Market_Cap  \
# 144   AGEN   NASDAQ                  Agenus Inc.        2.75  3.690648e+08
# 457   ARNA   NASDAQ  Arena Pharmaceuticals, Inc.       48.00  2.374217e+09
# 465   ARRY   NASDAQ         Array BioPharma Inc.       24.55  5.357143e+09
#
#      IPO_Year       Sector                                           Industry
# 144      2000  Health Care  Biotechnology: Biological Products (No Diagnos...
# 457      2000  Health Care                              Major Pharmaceuticals
# 465      2000  Health Care                              Major Pharmaceuticals

# %%
listing_2000.loc[listing_2000.Sector == "Health Care", 'Symbol']
# Out:
# 144    AGEN
# 457    ARNA
# 465    ARRY
# Name: Symbol, dtype: object

# %%
listing
# Out:
#      Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 0         A     NYSE     Agilent Technologies, Inc.       81.68  2.593470e+10
# 1        AA     NYSE              Alcoa Corporation       29.15  5.407810e+09
# 2      AABA   NASDAQ                    Altaba Inc.       75.39  4.278113e+10
# 3       AAC     NYSE             AAC Holdings, Inc.        2.16  5.314109e+07
# 4       AAL   NASDAQ  American Airlines Group, Inc.       34.02  1.527687e+10
# ...     ...      ...                            ...         ...           ...
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72  6.819191e+08
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79  2.147266e+09
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74  5.040782e+08
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85  1.653995e+08
# 6851   ZYXI   NASDAQ                    Zynex, Inc.        5.02  1.618349e+08
#
# ...

# %%
healthcare = listing[listing.Sector == 'Health Care']

# %%
healthcare_mask = listing.Sector == 'Health Care'

# %%
healthcare
# Out:
#      Symbol Exchange                                        Name  Last_Price  \
# 3       AAC     NYSE                          AAC Holdings, Inc.        2.16
# 19     ABBV     NYSE                                 AbbVie Inc.       82.95
# 20      ABC     NYSE  AmerisourceBergen Corporation (Holding Co)       74.00
# 23     ABEO   NASDAQ                    Abeona Therapeutics Inc.        7.54
# 24    ABEOW   NASDAQ                    Abeona Therapeutics Inc.        3.07
# ...     ...      ...                                         ...         ...
# 6842   ZSAN   NASDAQ                   Zosano Pharma Corporation        3.71
# 6846    ZTS     NYSE                                 Zoetis Inc.      101.33
# 6849   ZYME     NYSE                              Zymeworks Inc.       15.74
# 6850   ZYNE   NASDAQ               Zynerba Pharmaceuticals, Inc.        7.85
# 6851   ZYXI   NASDAQ                                 Zynex, Inc.        5.02
#
#         Market_Cap  IPO_Year       Sector  \
# ...

# %%
healthcare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 898 entries, 3 to 6851
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      898 non-null    object
#  1   Exchange    898 non-null    object
#  2   Name        898 non-null    object
#  3   Last_Price  898 non-null    float64
#  4   Market_Cap  853 non-null    float64
#  5   IPO_Year    898 non-null    int64
#  6   Sector      898 non-null    object
#  7   Industry    898 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 63.1+ KB

# %%
healthcare = listing.loc[healthcare_mask]
healthcare
# Out:
#      Symbol Exchange                                        Name  Last_Price  \
# 3       AAC     NYSE                          AAC Holdings, Inc.        2.16
# 19     ABBV     NYSE                                 AbbVie Inc.       82.95
# 20      ABC     NYSE  AmerisourceBergen Corporation (Holding Co)       74.00
# 23     ABEO   NASDAQ                    Abeona Therapeutics Inc.        7.54
# 24    ABEOW   NASDAQ                    Abeona Therapeutics Inc.        3.07
# ...     ...      ...                                         ...         ...
# 6842   ZSAN   NASDAQ                   Zosano Pharma Corporation        3.71
# 6846    ZTS     NYSE                                 Zoetis Inc.      101.33
# 6849   ZYME     NYSE                              Zymeworks Inc.       15.74
# 6850   ZYNE   NASDAQ               Zynerba Pharmaceuticals, Inc.        7.85
# 6851   ZYXI   NASDAQ                                 Zynex, Inc.        5.02
#
#         Market_Cap  IPO_Year       Sector  \
# ...

# %%
healthcare.dtypes
# Out:
# Symbol         object
# Exchange       object
# Name           object
# Last_Price    float64
# Market_Cap    float64
# IPO_Year        int64
# Sector         object
# Industry       object
# dtype: object

# %%
healthcare.dtypes == object
# Out:
# Symbol         True
# Exchange       True
# Name           True
# Last_Price    False
# Market_Cap    False
# IPO_Year      False
# Sector         True
# Industry       True
# dtype: bool

# %%
mask_1 = healthcare.dtypes != object

# %%
mask_1
# Out:
# Symbol        False
# Exchange      False
# Name          False
# Last_Price     True
# Market_Cap     True
# IPO_Year       True
# Sector        False
# Industry      False
# dtype: bool

# %%
healthcare.loc[:, mask_1] # include only numeric columns
# Out:
#       Last_Price    Market_Cap  IPO_Year
# 3           2.16  5.314109e+07      2014
# 19         82.95  1.226138e+11      2012
# 20         74.00  1.562065e+10      1969
# 23          7.54  3.615407e+08      1969
# 24          3.07           NaN      1969
# ...          ...           ...       ...
# 6842        3.71  4.441997e+07      2015
# 6846      101.33  4.855200e+10      2013
# 6849       15.74  5.040782e+08      2017
# 6850        7.85  1.653995e+08      2015
# 6851        5.02  1.618349e+08      1969
#
# [898 rows x 3 columns]

# %%
healthcare
# Out:
#      Symbol Exchange                                        Name  Last_Price  \
# 3       AAC     NYSE                          AAC Holdings, Inc.        2.16
# 19     ABBV     NYSE                                 AbbVie Inc.       82.95
# 20      ABC     NYSE  AmerisourceBergen Corporation (Holding Co)       74.00
# 23     ABEO   NASDAQ                    Abeona Therapeutics Inc.        7.54
# 24    ABEOW   NASDAQ                    Abeona Therapeutics Inc.        3.07
# ...     ...      ...                                         ...         ...
# 6842   ZSAN   NASDAQ                   Zosano Pharma Corporation        3.71
# 6846    ZTS     NYSE                                 Zoetis Inc.      101.33
# 6849   ZYME     NYSE                              Zymeworks Inc.       15.74
# 6850   ZYNE   NASDAQ               Zynerba Pharmaceuticals, Inc.        7.85
# 6851   ZYXI   NASDAQ                                 Zynex, Inc.        5.02
#
#         Market_Cap  IPO_Year       Sector  \
# ...

# %%
listing
# Out:
#      Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 0         A     NYSE     Agilent Technologies, Inc.       81.68  2.593470e+10
# 1        AA     NYSE              Alcoa Corporation       29.15  5.407810e+09
# 2      AABA   NASDAQ                    Altaba Inc.       75.39  4.278113e+10
# 3       AAC     NYSE             AAC Holdings, Inc.        2.16  5.314109e+07
# 4       AAL   NASDAQ  American Airlines Group, Inc.       34.02  1.527687e+10
# ...     ...      ...                            ...         ...           ...
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72  6.819191e+08
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79  2.147266e+09
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74  5.040782e+08
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85  1.653995e+08
# 6851   ZYXI   NASDAQ                    Zynex, Inc.        5.02  1.618349e+08
#
# ...

# %%
mask_1 = listing.Sector == 'Transportation'
mask_2 = listing.IPO_Year < 2000

# %%
transportation = listing.loc[mask_1 & mask_2]
transportation
# Out:
#      Symbol Exchange                                     Name  Last_Price  \
# 4       AAL   NASDAQ            American Airlines Group, Inc.       34.02
# 14     AAWW   NASDAQ             Atlas Air Worldwide Holdings       49.49
# 204    AIRT   NASDAQ                              Air T, Inc.       28.38
# 256     ALK     NYSE                   Alaska Air Group, Inc.       58.78
# 429    ARCB   NASDAQ                      ArcBest Corporation       33.09
# ...     ...      ...                                      ...         ...
# 6354    UPS     NYSE              United Parcel Service, Inc.      113.08
# 6364   USAK   NASDAQ                          USA Truck, Inc.       14.97
# 6620   WERN   NASDAQ                 Werner Enterprises, Inc.       34.74
# 6801   YRCW   NASDAQ                      YRC Worldwide, Inc.        7.87
# 6838    ZNH     NYSE  China Southern Airlines Company Limited       48.74
#
#         Market_Cap  IPO_Year          Sector  \
# ...

# %%
transportation_before_2000 = listing.loc[mask_1 & mask_2, ['Name', "Symbol", 'IPO_Year','Market_Cap']]
transportation_before_2000
# Out:
#                                          Name Symbol  IPO_Year    Market_Cap
# 4               American Airlines Group, Inc.    AAL      1969  1.527687e+10
# 14               Atlas Air Worldwide Holdings   AAWW      1969  1.274317e+09
# 204                               Air T, Inc.   AIRT      1969  5.745051e+07
# 256                    Alaska Air Group, Inc.    ALK      1969  7.265950e+09
# 429                       ArcBest Corporation   ARCB      1969  8.450621e+08
# ...                                       ...    ...       ...           ...
# 6354              United Parcel Service, Inc.    UPS      1999  7.877456e+10
# 6364                          USA Truck, Inc.   USAK      1992  1.285899e+08
# 6620                 Werner Enterprises, Inc.   WERN      1986  2.427913e+09
# 6801                      YRC Worldwide, Inc.   YRCW      1969  2.663506e+08
# 6838  China Southern Airlines Company Limited    ZNH      1997  1.195804e+10
#
# [76 rows x 4 columns]

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
og_1988 = summer.loc[summer.Year == 1988]

# %%
og_1988
# Out:
#        Year   City      Sport       Discipline                      Athlete  \
# 18051  1988  Seoul   Aquatics           Diving           MENA CAMPOS, Jesus
# 18052  1988  Seoul   Aquatics           Diving            LOUGANIS, Gregory
# 18053  1988  Seoul   Aquatics           Diving                    XIONG, Ni
# 18054  1988  Seoul   Aquatics           Diving  WYLAND-WILLIAMS, Wendy Lian
# 18055  1988  Seoul   Aquatics           Diving                  XU, Yan-Mei
# ...     ...    ...        ...              ...                          ...
# 19592  1988  Seoul  Wrestling  Wrestling Gre-R       KOMCHEV, Atanas Slavov
# 19593  1988  Seoul  Wrestling  Wrestling Gre-R        KOSKELA, Harri Matias
# 19594  1988  Seoul  Wrestling  Wrestling Gre-R     KOSLOWSKI, Dennis Marvin
# 19595  1988  Seoul  Wrestling  Wrestling Gre-R             WRONSKI, Andrzej
# 19596  1988  Seoul  Wrestling  Wrestling Gre-R              HIMMEL, Gerhard
#
# ...

# %%
og_1988.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1546 entries, 18051 to 19596
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        1546 non-null   int64
#  1   City        1546 non-null   object
#  2   Sport       1546 non-null   object
#  3   Discipline  1546 non-null   object
#  4   Athlete     1546 non-null   object
#  5   Country     1546 non-null   object
#  6   Gender      1546 non-null   object
#  7   Event       1546 non-null   object
#  8   Medal       1546 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 120.8+ KB

# %%
og_since_1992 = summer.loc[summer.Year >= 1992]
og_since_1992
# Out:
#        Year       City      Sport           Discipline  \
# 19597  1992  Barcelona   Aquatics               Diving
# 19598  1992  Barcelona   Aquatics               Diving
# 19599  1992  Barcelona   Aquatics               Diving
# 19600  1992  Barcelona   Aquatics               Diving
# 19601  1992  Barcelona   Aquatics               Diving
# ...     ...        ...        ...                  ...
# 31160  2012     London  Wrestling  Wrestling Freestyle
# 31161  2012     London  Wrestling  Wrestling Freestyle
# 31162  2012     London  Wrestling  Wrestling Freestyle
# 31163  2012     London  Wrestling  Wrestling Freestyle
# 31164  2012     London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender         Event   Medal
# 19597                  XIONG, Ni     CHN    Men  10M Platform  Bronze
# 19598                SUN, Shuwei     CHN    Men  10M Platform    Gold
# 19599            DONIE, Scott R.     USA    Men  10M Platform  Silver
# ...

# %%
ipo_year = listing.IPO_Year.between(2000, 2010)
ipo_year
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6847     True
# 6848    False
# 6849    False
# 6850    False
# 6851    False
# Name: IPO_Year, Length: 6852, dtype: bool

# %%
ipo_200_2010 = listing.loc[listing.IPO_Year.between(2000, 2010)]

# %%
ipo_year.index.name = 'IPO Year New'

# %%
ipo_year
# Out:
# IPO Year New
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6847     True
# 6848    False
# 6849    False
# 6850    False
# 6851    False
# Name: IPO_Year, Length: 6852, dtype: bool

# %%
ipo_200_2010.rename(columns={'Last_Price':'Last_Closing_Price'})
# Out:
#      Symbol Exchange                                   Name  \
# 26      ABG     NYSE            Asbury Automotive Group Inc
# 31      ABR     NYSE                     Arbor Realty Trust
# 44      ACC     NYSE        American Campus Communities Inc
# 50      ACH     NYSE  Aluminum Corporation of China Limited
# 52     ACHN   NASDAQ        Achillion Pharmaceuticals, Inc.
# ...     ...      ...                                    ...
# 6734    WTW   NASDAQ      Weight Watchers International Inc
# 6747   WYNN   NASDAQ                  Wynn Resorts, Limited
# 6764    XIN     NYSE             Xinyuan Real Estate Co Ltd
# 6828   ZGNX   NASDAQ                          Zogenix, Inc.
# 6847   ZUMZ   NASDAQ                            Zumiez Inc.
#
#       Last_Closing_Price    Market_Cap  IPO_Year             Sector  \
# 26                 72.64  1.416418e+09      2002  Consumer Durables
# 31                 13.52  1.162125e+09      2004  Consumer Services
# ...

# %%
og_60s = summer.loc[summer.Year.between(1960,1970)]

# %%
og_60s
# Out:
#        Year    City      Sport       Discipline                      Athlete  \
# 9792   1960    Rome   Aquatics           Diving           PHELPS, Brian Eric
# 9793   1960    Rome   Aquatics           Diving        WEBSTER, Robert David
# 9794   1960    Rome   Aquatics           Diving         TOBIAN, Gary Milburn
# 9795   1960    Rome   Aquatics           Diving               KRUTOVA, Ninel
# 9796   1960    Rome   Aquatics           Diving  KRÄMER-ENGEL-GULBIN, Ingrid
# ...     ...     ...        ...              ...                          ...
# 12710  1968  Mexico  Wrestling  Wrestling Gre-R                 METZ, Lothar
# 12711  1968  Mexico  Wrestling  Wrestling Gre-R            OLEINIK, Valentin
# 12712  1968  Mexico  Wrestling  Wrestling Gre-R          MARTINESCU, Nicolae
# 12713  1968  Mexico  Wrestling  Wrestling Gre-R     RADEV, Boyan Aleksandrov
# 12714  1968  Mexico  Wrestling  Wrestling Gre-R           YAKOVENKO, Nikolai
#
# ...

# %%
listing
# Out:
#              Symbol Exchange                           Name  Last_Price  \
# IPO Year New
# 0                 A     NYSE     Agilent Technologies, Inc.       81.68
# 1                AA     NYSE              Alcoa Corporation       29.15
# 2              AABA   NASDAQ                    Altaba Inc.       75.39
# 3               AAC     NYSE             AAC Holdings, Inc.        2.16
# 4               AAL   NASDAQ  American Airlines Group, Inc.       34.02
# ...             ...      ...                            ...         ...
# 6847           ZUMZ   NASDAQ                    Zumiez Inc.       26.72
# 6848            ZUO     NYSE                    Zuora, Inc.       19.79
# 6849           ZYME     NYSE                 Zymeworks Inc.       15.74
# 6850           ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85
# 6851           ZYXI   NASDAQ                    Zynex, Inc.        5.02
#
#                 Market_Cap  IPO_Year             Sector  \
# IPO Year New
# ...

# %%
my_listing = listing.loc[listing.IPO_Year.isin([1980,2010])]

# %%
my_listing.loc[listing.IPO_Year != 2010]
# Out:
#              Symbol Exchange                    Name  Last_Price  \
# IPO Year New
# 11             AAPL   NASDAQ              Apple Inc.      200.62
# 3539           KLAC   NASDAQ  KLA-Tencor Corporation      123.34
#
#                 Market_Cap  IPO_Year         Sector                Industry
# IPO Year New
# 11            9.459795e+11      1980     Technology  Computer Manufacturing
# 3539          2.018632e+10      1980  Capital Goods   Electronic Components

# %%
min_list_year = listing.IPO_Year.min()
max_list_year = listing.IPO_Year.max()
print(f"Range of IPO Years = {max_list_year - min_list_year}")
# Out:
# Range of IPO Years = 50

# %%
type(listing.IPO_Year.unique())
# Out:
# numpy.ndarray

# %%
ipo_years = listing.IPO_Year.unique().tolist()

# %%
ipo_years
# Out:
# [1999,
#  2016,
#  1969,
#  2014,
#  2013,
#  1980,
#  2011,
#  2015,
#  2012,
#  1994,
#  2002,
#  2004,
#  2018,
#  1985,
#  2019,
#  2001,
#  2006,
#  2000,
#  2007,
#  2017,
#  1988,
#  1986,
#  2009,
#  1997,
#  1995,
#  2003,
#  2008,
#  1992,
#  2010,
#  1991,
#  1983,
#  1996,
#  1972,
#  1998,
#  2005,
#  1993,
#  1987,
#  1981,
#  1989,
#  1990,
#  1982,
#  1984,
#  1973]

# %%
len(ipo_years)
# Out:
# 43

# %%
ipo_years.sort()

# %%
ipo_years
# Out:
# [1969,
#  1972,
#  1973,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]

# %%
mask_tech = listing.Sector == 'Technology'
mask_industry = listing.Industry == 'EDP Services'

listing.loc[ mask_tech & mask_industry]
# Out:
#              Symbol Exchange                             Name  Last_Price  \
# IPO Year New
# 2              AABA   NASDAQ                      Altaba Inc.       75.39
# 88              ADP   NASDAQ  Automatic Data Processing, Inc.      160.42
# 152            AGMH   NASDAQ          AGM Group Holdings Inc.       19.95
# 172            AGYS   NASDAQ                   Agilysys, Inc.       19.83
# 375             ANY   NASDAQ                  Sphere 3D Corp.        2.52
# ...             ...      ...                              ...         ...
# 6810             YY   NASDAQ                          YY Inc.       85.55
# 6823            ZEN     NYSE                    Zendesk, Inc.       83.34
# 6833           ZIXI   NASDAQ                  Zix Corporation        7.34
# 6837           ZNGA   NASDAQ                       Zynga Inc.        5.47
# 6841             ZS   NASDAQ                    Zscaler, Inc.       68.44
#
#                 Market_Cap  IPO_Year      Sector      Industry
# ...

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked   deck
# 0       False   False  False  False  False  False  False     False   True
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False   True
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False   True
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False   True
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False   True
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False   True
#
# [891 rows x 9 columns]

# %%
listing.isna().sum()
# Out:
# Symbol           0
# Exchange         0
# Name             0
# Last_Price       0
# Market_Cap     898
# IPO_Year         0
# Sector        1543
# Industry      1543
# dtype: int64

# %%
empty = listing.isna()

# %%
listing.notna().sum()
# Out:
# Symbol        6852
# Exchange      6852
# Name          6852
# Last_Price    6852
# Market_Cap    5954
# IPO_Year      6852
# Sector        5309
# Industry      5309
# dtype: int64

# %%
listing[empty]
# Out:
#              Symbol Exchange Name  Last_Price  Market_Cap  IPO_Year Sector  \
# IPO Year New
# 0               NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 1               NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 2               NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 3               NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 4               NaN      NaN  NaN         NaN         NaN       NaN    NaN
# ...             ...      ...  ...         ...         ...       ...    ...
# 6847            NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 6848            NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 6849            NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 6850            NaN      NaN  NaN         NaN         NaN       NaN    NaN
# 6851            NaN      NaN  NaN         NaN         NaN       NaN    NaN
#
#              Industry
# IPO Year New
# ...

# %%
listing.notna().sum()
# Out:
# Symbol        6852
# Exchange      6852
# Name          6852
# Last_Price    6852
# Market_Cap    5954
# IPO_Year      6852
# Sector        5309
# Industry      5309
# dtype: int64

# %%
listing.dropna()
# Out:
#              Symbol Exchange                           Name  Last_Price  \
# IPO Year New
# 0                 A     NYSE     Agilent Technologies, Inc.       81.68
# 1                AA     NYSE              Alcoa Corporation       29.15
# 2              AABA   NASDAQ                    Altaba Inc.       75.39
# 3               AAC     NYSE             AAC Holdings, Inc.        2.16
# 4               AAL   NASDAQ  American Airlines Group, Inc.       34.02
# ...             ...      ...                            ...         ...
# 6847           ZUMZ   NASDAQ                    Zumiez Inc.       26.72
# 6848            ZUO     NYSE                    Zuora, Inc.       19.79
# 6849           ZYME     NYSE                 Zymeworks Inc.       15.74
# 6850           ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85
# 6851           ZYXI   NASDAQ                    Zynex, Inc.        5.02
#
#                 Market_Cap  IPO_Year             Sector  \
# IPO Year New
# ...

# %%
listing.notna()
# Out:
#        Symbol  Exchange  Name  Last_Price  Market_Cap  IPO_Year  Sector  \
# IPO #
# 0        True      True  True        True        True      True    True
# 1        True      True  True        True        True      True    True
# 2        True      True  True        True        True      True    True
# 3        True      True  True        True        True      True    True
# 4        True      True  True        True        True      True    True
# ...       ...       ...   ...         ...         ...       ...     ...
# 6847     True      True  True        True        True      True    True
# 6848     True      True  True        True        True      True    True
# 6849     True      True  True        True        True      True    True
# 6850     True      True  True        True        True      True    True
# 6851     True      True  True        True        True      True    True
#
#        Industry
# IPO #
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
listing.index.name = 'IPO #'

# %%
listing.loc[listing.Market_Cap.isna()]
# Out:
#       Symbol Exchange                               Name  Last_Price  \
# IPO #
# 24     ABEOW   NASDAQ           Abeona Therapeutics Inc.        3.07
# 32     ABR^A     NYSE                 Arbor Realty Trust       25.62
# 33     ABR^B     NYSE                 Arbor Realty Trust       25.48
# 34     ABR^C     NYSE                 Arbor Realty Trust       26.27
# 41     ACAMU   NASDAQ  Acamar Partners Acquisition Corp.       10.01
# ...      ...      ...                                ...         ...
# 6818    ZB^A     NYSE          Zions Bancorporation N.A.       23.70
# 6819    ZB^G     NYSE          Zions Bancorporation N.A.       27.62
# 6820    ZB^H     NYSE          Zions Bancorporation N.A.       25.55
# 6830   ZIONW   NASDAQ          Zions Bancorporation N.A.       14.74
# 6843   ZTEST   NASDAQ                  BATS BZX Exchange       10.10
#
#        Market_Cap  IPO_Year       Sector               Industry
# IPO #
# ...

# %%
avg_market_cap = listing['Market_Cap'].mean()
avg_market_cap
# Out:
# 7174440219.091951

# %%
listing.fillna(value={'Market_Cap':avg_market_cap},inplace=True)

# %%
listing.isna().sum()
# Out:
# Symbol           0
# Exchange         0
# Name             0
# Last_Price       0
# Market_Cap       0
# IPO_Year         0
# Sector        1543
# Industry      1543
# dtype: int64

# %%
listing.fillna(value={'Sector':'No Sector Information'},inplace=True)

# %%
no_sect_info_mask = listing.Sector == 'No Sector Information'

# %%
listing.loc[no_sect_info_mask]
# Out:
#       Symbol Exchange                                               Name  \
# IPO #
# 15      AAXJ   NASDAQ  iShares MSCI All Country Asia ex Japan Index Fund
# 22      ABDC   NASDAQ                             Alcentra Capital Corp.
# 32     ABR^A     NYSE                                 Arbor Realty Trust
# 33     ABR^B     NYSE                                 Arbor Realty Trust
# 34     ABR^C     NYSE                                 Arbor Realty Trust
# ...      ...      ...                                                ...
# 6819    ZB^G     NYSE                          Zions Bancorporation N.A.
# 6820    ZB^H     NYSE                          Zions Bancorporation N.A.
# 6825      ZF     NYSE                      Virtus Total Return Fund Inc.
# 6843   ZTEST   NASDAQ                                  BATS BZX Exchange
# 6845     ZTR     NYSE          Virtus Global Dividend & Income Fund Inc.
#
#        Last_Price    Market_Cap  IPO_Year                 Sector Industry
# IPO #
# ...

# %%
listing['Market_Cap'].astype('int64')
# Out:
# IPO #
# 0       25934696179
# 1        5407809589
# 2       42781131315
# 3          53141086
# 4       15276869742
#            ...
# 6847      681919062
# 6848     2147266454
# 6849      504078206
# 6850      165399468
# 6851      161834880
# Name: Market_Cap, Length: 6852, dtype: int64

# %%
listing['Market_Cap'] = listing['Market_Cap'].astype('int')

# %%
listing
# Out:
#       Symbol Exchange                           Name  Last_Price  Market_Cap  \
# IPO #
# 0          A     NYSE     Agilent Technologies, Inc.       81.68 -2147483648
# 1         AA     NYSE              Alcoa Corporation       29.15 -2147483648
# 2       AABA   NASDAQ                    Altaba Inc.       75.39 -2147483648
# 3        AAC     NYSE             AAC Holdings, Inc.        2.16    53141086
# 4        AAL   NASDAQ  American Airlines Group, Inc.       34.02 -2147483648
# ...      ...      ...                            ...         ...         ...
# 6847    ZUMZ   NASDAQ                    Zumiez Inc.       26.72   681919062
# 6848     ZUO     NYSE                    Zuora, Inc.       19.79  2147266454
# 6849    ZYME     NYSE                 Zymeworks Inc.       15.74   504078206
# 6850    ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85   165399468
# 6851    ZYXI   NASDAQ                    Zynex, Inc.        5.02   161834880
#
# ...

# %%
df = pd.read_csv('sales_data_types.csv')

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0          10002.0  Quest Industries  $125,000.00    $162500.00
# 1         552278.0    Smith Plumbing  $920,000.00  $101,2000.00
# 2          23477.0   ACME Industrial   $50,000.00     $62500.00
# 3          24900.0        Brekke LTD  $350,000.00    $490000.00
# 4         651029.0         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df['2016']
# Out:
# 0    $125,000.00
# 1    $920,000.00
# 2     $50,000.00
# 3    $350,000.00
# 4     $15,000.00
# Name: 2016, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer Number  5 non-null      float64
#  1   Customer Name    5 non-null      object
#  2   2016             5 non-null      object
#  3   2017             5 non-null      object
#  4   Percent Growth   5 non-null      object
#  5   Jan Units        5 non-null      object
#  6   Month            5 non-null      int64
#  7   Day              5 non-null      int64
#  8   Year             5 non-null      int64
#  9   Active           5 non-null      object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 528.0+ bytes

# %%
df.dtypes
# Out:
# Customer Number    float64
# Customer Name       object
# 2016                object
# 2017                object
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
df['Customer Number'].astype('int')
# Out:
# 0     10002
# 1    552278
# 2     23477
# 3     24900
# 4    651029
# Name: Customer Number, dtype: int32

# %%
df['Customer Number'] = df['Customer Number'].astype('int')

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
df['2016']
# Out:
# 0    $125,000.00
# 1    $920,000.00
# 2     $50,000.00
# 3    $350,000.00
# 4     $15,000.00
# Name: 2016, dtype: object

# %%
text = '$125,000.00'

# %%
def convert_str_to_num(val):
    new_val = val.replace(',', '').replace('$', '')
    return float(new_val)

# %%
df['2016'].apply(convert_str_to_num)
# Out:
# 0    125000.0
# 1    920000.0
# 2     50000.0
# 3    350000.0
# 4     15000.0
# Name: 2016, dtype: float64

# %%
# df['2016'] = df['2016'].apply(convert_str_to_num)
# df['2017'] = df['2017'].apply(convert_str_to_num)

df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active
# 0      500.0      1   10  2015    True
# 1      700.0      6   15  2014    True
# 2      125.0      3   29  2016    True
# 3       75.0     10   27  2015    True
# 4        0.0      2    2  2014   False

# %%
df.dtypes
# Out:
# Customer Number      int32
# Customer Name       object
# 2016               float64
# 2017               float64
# Percent Growth      object
# Jan Units           object
# Month                int64
# Day                  int64
# Year                 int64
# Active              object
# dtype: object

# %%
df['Percent Growth'] = df['Percent Growth'].apply(lambda x: x.replace('%', '')).astype('float') /100

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#   Jan Units  Month  Day  Year  Active
# 0       500      1   10  2015   False
# 1       700      6   15  2014   False
# 2       125      3   29  2016   False
# 3        75     10   27  2015   False
# 4    Closed      2    2  2014   False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer Number  5 non-null      int32
#  1   Customer Name    5 non-null      object
#  2   2016             5 non-null      float64
#  3   2017             5 non-null      float64
#  4   Percent Growth   5 non-null      float64
#  5   Jan Units        5 non-null      object
#  6   Month            5 non-null      int64
#  7   Day              5 non-null      int64
#  8   Year             5 non-null      int64
#  9   Active           5 non-null      bool
# dtypes: bool(1), float64(3), int32(1), int64(3), object(2)
# memory usage: 473.0+ bytes

# %%
def active_cust_conversion(val):
    """Convert string 'Y' to True and 'N' to False"""
    
    if val == 'Y':
        return True
    elif val == 'N':
        return False

# %%
# df["Active"] = np.where(df["Active"] == "Y", True, False)

# df['Active'] = df['Active'].apply(active_cust_conversion)

# %%
df
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#    Percent Growth Jan Units  Month  Day  Year  Active
# 0            0.30       500      1   10  2015    True
# 1            0.10       700      6   15  2014    True
# 2            0.25       125      3   29  2016    True
# 3            0.04        75     10   27  2015    True
# 4           -0.15    Closed      2    2  2014   False

# %%
# df["Active"] = pd.DataFrame(['Y','Y','Y', 'Y','N'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer Number  5 non-null      int32
#  1   Customer Name    5 non-null      object
#  2   2016             5 non-null      float64
#  3   2017             5 non-null      float64
#  4   Percent Growth   5 non-null      float64
#  5   Jan Units        5 non-null      object
#  6   Month            5 non-null      int64
#  7   Day              5 non-null      int64
#  8   Year             5 non-null      int64
#  9   Active           5 non-null      bool
# dtypes: bool(1), float64(3), int32(1), int64(3), object(2)
# memory usage: 473.0+ bytes

# %%
pd.to_numeric(df['Jan Units'],errors='coerce')
# Out:
# 0    500.0
# 1    700.0
# 2    125.0
# 3     75.0
# 4      NaN
# Name: Jan Units, dtype: float64

# %%
df['Jan Units'] = pd.to_numeric(df['Jan Units'],errors='coerce')

# %%
df = df.fillna(0)

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active
# 0      500.0      1   10  2015    True
# 1      700.0      6   15  2014    True
# 2      125.0      3   29  2016    True
# 3       75.0     10   27  2015    True
# 4        0.0      2    2  2014   False

# %%
total_sales = df['2016'] + df['2017']
total_sales
# Out:
# 0     287500.0
# 1    1932000.0
# 2     112500.0
# 3     840000.0
# 4      27750.0
# dtype: float64

# %%
# df['Total Sales'] = df['2016'] + df['2017']

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active  Total Sales
# 0      500.0      1   10  2015    True     287500.0
# 1      700.0      6   15  2014    True    1932000.0
# 2      125.0      3   29  2016    True     112500.0
# 3       75.0     10   27  2015    True     840000.0
# 4        0.0      2    2  2014   False      27750.0

# %%
# pd.to_datetime(df[['Month','Day', 'Year']])
# Out:
# 0   2015-01-10
# 1   2014-06-15
# 2   2016-03-29
# 3   2015-10-27
# 4   2014-02-02
# dtype: datetime64[ns]

# %%
# df['Date'] = pd.to_datetime(df[['Month','Day', 'Year']])

# %%
df
# Out:
#    Customer Number     Customer Name      2016       2017  Percent Growth  \
# 0            10002  Quest Industries  125000.0   162500.0            0.30
# 1           552278    Smith Plumbing  920000.0  1012000.0            0.10
# 2            23477   ACME Industrial   50000.0    62500.0            0.25
# 3            24900        Brekke LTD  350000.0   490000.0            0.04
# 4           651029         Harbor Co   15000.0    12750.0           -0.15
#
#    Jan Units  Month  Day  Year  Active  Total Sales       Date
# 0      500.0      1   10  2015    True     287500.0 2015-01-10
# 1      700.0      6   15  2014    True    1932000.0 2014-06-15
# 2      125.0      3   29  2016    True     112500.0 2016-03-29
# 3       75.0     10   27  2015    True     840000.0 2015-10-27
# 4        0.0      2    2  2014   False      27750.0 2014-02-02

# %%
dtype = {"Customer Number":"int"}

    

df_2 = pd.read_csv('sales_data_types.csv', dtype=dtype )

# %%
df_2
# Out:
#    Customer Number     Customer Name         2016          2017  \
# 0            10002  Quest Industries  $125,000.00    $162500.00
# 1           552278    Smith Plumbing  $920,000.00  $101,2000.00
# 2            23477   ACME Industrial   $50,000.00     $62500.00
# 3            24900        Brekke LTD  $350,000.00    $490000.00
# 4           651029         Harbor Co   $15,000.00     $12750.00
#
#   Percent Growth Jan Units  Month  Day  Year Active
# 0         30.00%       500      1   10  2015      Y
# 1         10.00%       700      6   15  2014      Y
# 2         25.00%       125      3   29  2016      Y
# 3          4.00%        75     10   27  2015      Y
# 4        -15.00%    Closed      2    2  2014      N

# %%
titanic.agg(['mean', 'std'])
# Out:
# C:\Users\Danijel.Djordjic\AppData\Local\Temp\ipykernel_7396\2085952059.py:1: FutureWarning: ['sex', 'embarked', 'deck'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   titanic.agg(['mean', 'std'])
#       survived    pclass        age     sibsp     parch       fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594  32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057  49.693429
