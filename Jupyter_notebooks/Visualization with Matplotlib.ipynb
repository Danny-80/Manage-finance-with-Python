# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.plot()
plt.show()

# %%
titanic.plot(subplots=True, figsize=(15,12))
plt.show()

# %%
titanic.plot(subplots=True, figsize=(15,12), sharex = False) # x axis is not shared 
plt.show()

# %%
titanic.plot(subplots=True, figsize=(15,12), sharex = False, sharey=True)  # y axis have the same scale for all columns
plt.show()

# %%
# applying plot only on one column

titanic.age.plot( figsize=(10,4))  # y axis have the same scale for all columns
plt.show()

# %% [markdown]
# ### Customization

# %%
titanic.age.plot( figsize=(12,8), fontsize=13, c='green',linestyle= '-', xlim= (0,900), ylim = (0,89))  
plt.title('Titanic - Ages', fontsize=12)
plt.legend(loc=2, fontsize=8)
plt.xlabel('Passenger No', fontsize=10)
plt.ylabel('Passenger Age', fontsize=10)
plt.grid()
plt.show()

# %%
xticks = [x for x in range(0,900, 50)]
xticks
# Out:
# [0,
#  50,
#  100,
#  150,
#  200,
#  250,
#  300,
#  350,
#  400,
#  450,
#  500,
#  550,
#  600,
#  650,
#  700,
#  750,
#  800,
#  850]

# %%
yticks = np.arange(0,81,10)
yticks
# Out:
# array([ 0, 10, 20, 30, 40, 50, 60, 70, 80])

# %%
titanic.age.plot( figsize=(12,8), fontsize=13, c='green',linestyle= '-', xlim= (0,900), ylim = (0,89), xticks=xticks, yticks=yticks)  
plt.title('Titanic - Ages', fontsize=12)
plt.legend(loc=2, fontsize=8)
plt.xlabel('Passenger No', fontsize=10)
plt.ylabel('Passenger Age', fontsize=10)
plt.grid()
plt.show()

# %%
titanic.age.plot( figsize=(12,8), fontsize=13, c='green',linestyle= '-', xlim= (0,900), ylim = (0,89),
                 xticks=xticks, yticks=yticks, rot='45')  
plt.title('Titanic - Ages', fontsize=12)
plt.legend(loc=2, fontsize=10, title='Passenger age')
plt.xlabel('Passenger No', fontsize=10)
plt.ylabel('Passenger Age', fontsize=10)
# plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn')

# %%
titanic.age.plot( figsize=(12,8), fontsize=13, c='green',linestyle= '-', xlim= (0,900), ylim = (0,89),
                 xticks=xticks, yticks=yticks, rot='45')  
plt.title('Titanic - Ages', fontsize=12)
plt.legend(loc=2, fontsize=8)
plt.xlabel('Passenger No', fontsize=10)
plt.ylabel('Passenger Age', fontsize=10)
# plt.grid()
plt.show()

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age.value_counts(bins = 10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: age, dtype: int64

# %%
titanic.age.plot(kind='line',figsize=(12,8),fontsize=15)
plt.show()

# %%
titanic.age.plot(kind='hist',figsize=(12,8),fontsize=15, bins = 80, xticks=[x for x in range(0,85, 5)])
plt.show()

# %%
titanic.age.hist(figsize = (12,8), bins = 80, xlabelsize= 15, ylabelsize=15)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize = (12,8))
plt.hist(titanic.age, bins = 80, density=False, cumulative=False)
plt.plot();

# %% [markdown]
# ### Scaterplots

# %%
titanic.plot(kind="scatter", x = 'age', y = 'fare', figsize = (15,8), ylim = (0,600),
             yticks = list(range(0,600,50)), fontsize =12, c = 'survived', marker = 'o', s = 45, colormap = 'viridis')
plt.show()

# %%
plt.plot(titanic.age, linestyle=':')

# %%
titanic.sex.hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(titanic['pclass'].values, bins=20, density=30)
plt.xticks([1,2,3], [np.arange(1,4)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 plt.hist(titanic['pclass'].values, bins=20, density=30)
# ----> 2 plt.xticks([1,2,3], [np.arange(1,4)])
#
# File ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1816, in xticks(ticks, labels, **kwargs)
#    1814         l.update(kwargs)
#    1815 else:
# -> 1816     labels = ax.set_xticklabels(labels, **kwargs)
#    1818 return locs, labels
#
# File ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# ...

# %%
np.arange(1,4)
# Out:
# array([1, 2, 3])

# %%
titanic.plot(kind= 'scatter', x='age', y='fare', figsize=(15,8));

# %%
plt.style.use('seaborn')

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=titanic, x='sex')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1, palette = 'viridis')
sns.countplot(data=titanic, x='sex', hue= 'pclass')
plt.show()

# %%
sns.set_theme(style='ticks')
df = sns.load_dataset('anscombe')

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
# show the results of a linear regression with each dataset
sns.lmplot(data=df, x= 'x', y='y', col='dataset', hue='dataset', col_wrap=2, palette='muted',
          ci=None, height=4,scatter_kws={'s':50, 'alpha':1})

# %% [markdown]
# ### Categorical Plots

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.stripplot(data=titanic, x='sex', y='age',jitter=True, hue='survived', dodge=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.swarmplot(data=titanic, x='sex', y='age', hue='pclass', dodge=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x='sex', y='age', hue='pclass', dodge=True)
sns.swarmplot(data=titanic, x='sex', y='age', hue='pclass', dodge=True, c='yellow')

plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, y='age', x='pclass', hue='sex', dodge=True, split= False)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.barplot(data=titanic, x='pclass', y='age', hue='sex', dodge=True, orient='v')

plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.pointplot(data=titanic, x='pclass', y='age', hue='sex', dodge=True)

plt.show()

# %% [markdown]
# # Jointplots / Regression

# %%
sns.set(font_scale=1.5)
sns.jointplot(data=titanic, x='age', y='fare', height=8, kind='scatter')

# %%
sns.set(font_scale=1.5)
sns.jointplot(data=titanic, x='age', y='fare', height=8, kind='kde') # kernel density estimate

# %%
sns.set(font_scale=1.5)
sns.jointplot(data=titanic, x='age', y='fare', height=8, kind='reg');

# %%
sns.lmplot(titanic, x='age', y='fare', aspect=1, height=8, hue='sex' , n_boot=1000)

# %%
sns.lmplot(titanic, x='age', y='fare', aspect=1, height=8, col='sex')

# %%
sns.lmplot(titanic, x='age', y='fare', aspect=1, height=5, row='sex')

# %%
sns.lmplot(titanic, x='age', y='survived', aspect=1, height=8, logistic=True)

# %% [markdown]
# # Matrixplots and Heatmaps

# %%
pd.crosstab(titanic.sex,titanic.pclass)
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
sns.set(font_scale=1.4)
h = sns.heatmap(data=pd.crosstab(titanic.sex,titanic.pclass), annot=True, fmt='d', cmap='Oranges', vmax=150)

# %%
pd.crosstab(titanic.sex, titanic.pclass, values=titanic.survived, aggfunc='mean')
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
sns.set(font_scale=1.4)
g = sns.heatmap(data=pd.crosstab(titanic.sex, titanic.pclass, values=titanic.survived, aggfunc='mean'), annot=True, vmax=1)

# %%
titanic.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(titanic.corr(), annot=True, cmap='Reds')
# Out:
# <AxesSubplot:>
