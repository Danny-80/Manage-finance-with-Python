# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
summer = pd.read_csv('summer.csv')
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
# summer.drop(columns=['Sport', 'Discipline'], inplace=True)
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.drop(labels='Event', axis=1, inplace=True)

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender   Medal
# 0                  HAJOS, Alfred     HUN    Men    Gold
# 1               HERSCHMANN, Otto     AUT    Men  Silver
# 2              DRIVAS, Dimitrios     GRE    Men  Bronze
# 3             MALOKINIS, Ioannis     GRE    Men    Gold
# ...

# %%
summer = pd.read_csv('summer.csv')
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
# summer = summer.loc[:, ['Sport','Year']]
# summer = summer.loc[:, 'Sport']
summer.loc[:, ['Sport', 'Year', 'Country']]
# Out:
#            Sport  Year Country
# 0       Aquatics  1896     HUN
# 1       Aquatics  1896     AUT
# 2       Aquatics  1896     GRE
# 3       Aquatics  1896     GRE
# 4       Aquatics  1896     GRE
# ...          ...   ...     ...
# 31160  Wrestling  2012     POL
# 31161  Wrestling  2012     IRI
# 31162  Wrestling  2012     RUS
# 31163  Wrestling  2012     ARM
# 31164  Wrestling  2012     SWE
#
# [31165 rows x 3 columns]

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer = pd.read_csv('summer.csv', index_col='Athlete')
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.head(7)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# HERSCHMANN, Otto                   100M Freestyle  Silver
# DRIVAS, Dimitrios      100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis     100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon     100M Freestyle For Sailors  Silver
# ...

# %%
summer.drop(index='HAJOS, Alfred')
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios      1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.drop(index = ['HAJOS, Alfred', 'HERSCHMANN, Otto'], inplace=True)

# %%
summer.drop(labels='DRIVAS, Dimitrios', inplace=True)

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios      1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis           1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios      1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer = summer.loc[summer.Year == 1996]
summer
# Out:
#                      Year     City      Sport       Discipline Country Gender  \
# Athlete
# XIAO, Hailiang       1996  Atlanta   Aquatics           Diving     CHN    Men
# SAUTIN, Dmitry       1996  Atlanta   Aquatics           Diving     RUS    Men
# HEMPEL, Jan          1996  Atlanta   Aquatics           Diving     GER    Men
# CLARK, Mary Ellen    1996  Atlanta   Aquatics           Diving     USA  Women
# FU, Mingxia          1996  Atlanta   Aquatics           Diving     CHN  Women
# ...                   ...      ...        ...              ...     ...    ...
# OLEYNYK, Vyacheslav  1996  Atlanta  Wrestling  Wrestling Gre-R     UKR    Men
# FAFINSKI, Jacek      1996  Atlanta  Wrestling  Wrestling Gre-R     POL    Men
# LJUNGBERG, Mikael    1996  Atlanta  Wrestling  Wrestling Gre-R     SWE    Men
# WRONSKI, Andrzej     1996  Atlanta  Wrestling  Wrestling Gre-R     POL    Men
# LISHTVAN, Sergey     1996  Atlanta  Wrestling  Wrestling Gre-R     BLR    Men
#
# ...

# %%
summer = pd.read_csv('summer.csv', index_col='Athlete')
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
mask1 = summer['Year']  == 1996
mask2 = summer.Sport == 'Acquatics'

# %%
summer = summer.loc[mask1 | mask2]
summer
# Out:
#                      Year     City      Sport       Discipline Country Gender  \
# Athlete
# XIAO, Hailiang       1996  Atlanta   Aquatics           Diving     CHN    Men
# SAUTIN, Dmitry       1996  Atlanta   Aquatics           Diving     RUS    Men
# HEMPEL, Jan          1996  Atlanta   Aquatics           Diving     GER    Men
# CLARK, Mary Ellen    1996  Atlanta   Aquatics           Diving     USA  Women
# FU, Mingxia          1996  Atlanta   Aquatics           Diving     CHN  Women
# ...                   ...      ...        ...              ...     ...    ...
# OLEYNYK, Vyacheslav  1996  Atlanta  Wrestling  Wrestling Gre-R     UKR    Men
# FAFINSKI, Jacek      1996  Atlanta  Wrestling  Wrestling Gre-R     POL    Men
# LJUNGBERG, Mikael    1996  Atlanta  Wrestling  Wrestling Gre-R     SWE    Men
# WRONSKI, Andrzej     1996  Atlanta  Wrestling  Wrestling Gre-R     POL    Men
# LISHTVAN, Sergey     1996  Atlanta  Wrestling  Wrestling Gre-R     BLR    Men
#
# ...

# %%
(summer.Year == 1996).value_counts()
# Out:
# True    1859
# Name: Year, dtype: int64

# %%
1996 in summer.Year.values
# Out:
# True

# %%
(summer.Sport.isin(['Acquatics']).any())
# Out:
# False

# %%
(summer.Sport == 'Acquatics').any()
# Out:
# False

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic['Random_numbers'] = np.random.randint(0,100, len(titanic))

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#      Random_numbers
# 0                 7
# 1                66
# 2                94
# ...

# %%
titanic.drop(columns='Zeros')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 titanic.drop(columns='Zeros')
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
# ...

# %%
titanic["Ones"] = np.ones(shape=(len(titanic), 1))
titanic

# %% [markdown]
# ## Arithemtic operations

# %%
titanic = pd.read_csv('titanic.csv')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
# replacing missing values for age feature

# titanic.age.isna().sum()
titanic.age.fillna(titanic.age.mean(), inplace=True)
titanic.head(15)
# Out:
#     survived  pclass     sex        age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.000000      1      0   7.2500        S  NaN
# 1          1       1  female  38.000000      1      0  71.2833        C    C
# 2          1       3  female  26.000000      0      0   7.9250        S  NaN
# 3          1       1  female  35.000000      1      0  53.1000        S    C
# 4          0       3    male  35.000000      0      0   8.0500        S  NaN
# 5          0       3    male  29.699118      0      0   8.4583        Q  NaN
# 6          0       1    male  54.000000      0      0  51.8625        S    E
# 7          0       3    male   2.000000      3      1  21.0750        S  NaN
# 8          1       3  female  27.000000      0      2  11.1333        S  NaN
# 9          1       2  female  14.000000      1      0  30.0708        C  NaN
# 10         1       3  female   4.000000      1      1  16.7000        S    G
# ...

# %% [markdown]
# #### Add/Sub/Mul/Div of Columns

# %%
titanic.sibsp + titanic.parch
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic.sibsp.add(titanic.parch)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic['No_relat'] = titanic.sibsp.add(titanic.parch)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
#      No_relat
# 0           1
# ...

# %%
sales = pd.read_csv('sales.csv', index_col=0)
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.Mon + sales.Thu
# Out:
# Steven      NaN
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
sales.Mon.add(sales.Thu, fill_value=0)
# Out:
# Steven     34.0
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
sales['perc_Bonus'] = [.12,.15,.10,.20]

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus
# Steven   34   27   15   NaN   33        0.12
# Mike     45    9   74  87.0   12        0.15
# Andi     17   33   54   8.0   29        0.10
# Paul     87   67   27  45.0    7        0.20

# %%
sales.Thu * sales.perc_Bonus
# Out:
# Steven      NaN
# Mike      13.05
# Andi       0.80
# Paul       9.00
# dtype: float64

# %%
sales.Thu.mul(sales.perc_Bonus, fill_value=0)
# Out:
# Steven     0.00
# Mike      13.05
# Andi       0.80
# Paul       9.00
# dtype: float64

# %%
sales.Thu.multiply(sales.perc_Bonus, fill_value=0)
# Out:
# Steven     0.00
# Mike      13.05
# Andi       0.80
# Paul       9.00
# dtype: float64

# %%
sales.iloc[:, :-1]
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.iloc[:, :-1].sum(axis=1).mul(sales.perc_Bonus)
# Out:
# Steven    13.08
# Mike      34.05
# Andi      14.10
# Paul      46.60
# dtype: float64

# %%
109*.12
# Out:
# 13.08

# %%
sales['Weekly_total'] = sales.iloc[:, :-1].sum(axis=1)
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus  Weekly_total
# Steven   34   27   15   NaN   33        0.12         109.0
# Mike     45    9   74  87.0   12        0.15         227.0
# Andi     17   33   54   8.0   29        0.10         141.0
# Paul     87   67   27  45.0    7        0.20         233.0

# %%
sales['Weekly_bonus'] = sales.iloc[:, :-1].sum(axis=1).mul(sales.perc_Bonus)
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus  Weekly_total  Weekly_bonus
# Steven   34   27   15   NaN   33        0.12         109.0       13.0944
# Mike     45    9   74  87.0   12        0.15         227.0       34.0725
# Andi     17   33   54   8.0   29        0.10         141.0       14.1100
# Paul     87   67   27  45.0    7        0.20         233.0       46.6400

# %%
sales.iloc[:, [0,1,2,3,4, 7,5, 6]]
# Out:
#         Mon  Tue  Wed   Thu  Fri  Weekly_bonus  perc_Bonus  Weekly_total
# Steven   34   27   15   NaN   33       13.0944        0.12         109.0
# Mike     45    9   74  87.0   12       34.0725        0.15         227.0
# Andi     17   33   54   8.0   29       14.1100        0.10         141.0
# Paul     87   67   27  45.0    7       46.6400        0.20         233.0

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.age.fillna(titanic.age.mean(), inplace=True)

# %%
1912- titanic.age
# Out:
# 0      1890.000000
# 1      1874.000000
# 2      1886.000000
# 3      1877.000000
# 4      1877.000000
#           ...
# 886    1885.000000
# 887    1893.000000
# 888    1882.300882
# 889    1886.000000
# 890    1880.000000
# Name: age, Length: 891, dtype: float64

# %%
titanic['YoB'] = titanic.age.sub(1912, fill_value=None ).mul(-1).astype('int')

# %%
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
#       YoB
# 0    1890
# ...

# %%
fx_rate = 1.1

# %%
titanic['Euro_fare'] = titanic.fare.div(fx_rate)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
#       YoB  Euro_fare
# ...

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus  Weekly_total  Weekly_bonus
# Steven   34   27   15   NaN   33        0.12         109.0       13.0944
# Mike     45    9   74  87.0   12        0.15         227.0       34.0725
# Andi     17   33   54   8.0   29        0.10         141.0       14.1100
# Paul     87   67   27  45.0    7        0.20         233.0       46.6400

# %%
fixed_cost = 5

# %%
sales.iloc[:,:-3].sub(fixed_cost, fill_value=0)
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   29   22   10  -5.0   28
# Mike     40    4   69  82.0    7
# Andi     12   28   49   3.0   24
# Paul     82   62   22  40.0    2

# %%
lot_size = 10
bonus_per_lot = 1.25

# %%
sales.iloc[:,:-3].floordiv(lot_size,fill_value=0).mul(bonus_per_lot).sum(axis=1)
# Out:
# Steven    11.25
# Mike      25.00
# Andi      13.75
# Paul      25.00
# dtype: float64

# %% [markdown]
# ## Creating DataFrames from Scratch

# %%
player = ['Danijel', "Messi", "Neymar", 'Ivanka', "Junior"]
nationality = ['Serbia', 'Argentina', 'Brasil', 'France', "Germany"]
club = ['Barcelona', 'Juventus', 'Paris SG', 'Crvena Zvezda', 'Bayern']
world_champion = [False, False, True, True, False]
height = [1.7,1.87,1.75,1.93,1.84]
goals = [45,44,28,21,0]

# %%
dic = {'Player':player, 'Nationality':nationality, 'Club':club,'World_Champion':world_champion,
      'Height':height,'Goals_2018':goals}
dic
# Out:
# {'Player': ['Danijel', 'Messi', 'Neymar', 'Ivanka', 'Junior'],
#  'Nationality': ['Serbia', 'Argentina', 'Brasil', 'France', 'Germany'],
#  'Club': ['Barcelona', 'Juventus', 'Paris SG', 'Crvena Zvezda', 'Bayern'],
#  'World_Champion': [False, False, True, True, False],
#  'Height': [1.7, 1.87, 1.75, 1.93, 1.84],
#  'Goals_2018': [45, 44, 28, 21, 0]}

# %%
df = pd.DataFrame(data=dic)
df
# Out:
#     Player Nationality           Club  World_Champion  Height  Goals_2018
# 0  Danijel      Serbia      Barcelona           False    1.70          45
# 1    Messi   Argentina       Juventus           False    1.87          44
# 2   Neymar      Brasil       Paris SG            True    1.75          28
# 3   Ivanka      France  Crvena Zvezda            True    1.93          21
# 4   Junior     Germany         Bayern           False    1.84           0

# %%
df1 = pd.DataFrame(nationality,columns=['Country'], index=list([1,2,3,4,5]))
df1
# Out:
#      Country
# 1     Serbia
# 2  Argentina
# 3     Brasil
# 4     France
# 5    Germany

# %%
players = df.set_index('Player')
players
# Out:
#         Nationality           Club  World_Champion  Height  Goals_2018
# Player
# Danijel      Serbia      Barcelona           False    1.70          45
# Messi     Argentina       Juventus           False    1.87          44
# Neymar       Brasil       Paris SG            True    1.75          28
# Ivanka       France  Crvena Zvezda            True    1.93          21
# Junior      Germany         Bayern           False    1.84           0

# %%
players.loc['Ivanka','Nationality'] = 'Serbia'

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Danijel to Junior
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nationality     5 non-null      object
#  1   Club            5 non-null      object
#  2   World_Champion  5 non-null      bool
#  3   Height          5 non-null      float64
#  4   Goals_2018      5 non-null      int64
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 377.0+ bytes

# %%
list(zip(nationality,club,height,goals,world_champion))
# Out:
# [('Serbia', 'Barcelona', 1.7, 45, False),
#  ('Argentina', 'Juventus', 1.87, 44, False),
#  ('Brasil', 'Paris SG', 1.75, 28, True),
#  ('France', 'Crvena Zvezda', 1.93, 21, True),
#  ('Germany', 'Bayern', 1.84, 0, False)]

# %%
zipped = list(zip(nationality,club,height,goals,world_champion))

# %%
danijel,_,_,_,_ = zipped

# %%
danijel
# Out:
# ('Serbia', 'Barcelona', 1.7, 45, False)

# %%
df2 = pd.Series(index=player,data=nationality, name='Nationality').to_frame()
df2
# Out:
#         Nationality
# Danijel      Serbia
# Messi     Argentina
# Neymar       Brasil
# Ivanka       France
# Junior      Germany

# %%
df2
# Out:
#         Nationality
# Danijel      Serbia
# Messi     Argentina
# Neymar       Brasil
# Ivanka       France
# Junior      Germany

# %%
df2['Club'] = club
df2
# Out:
#         Nationality           Club
# Danijel      Serbia      Barcelona
# Messi     Argentina       Juventus
# Neymar       Brasil       Paris SG
# Ivanka       France  Crvena Zvezda
# Junior      Germany         Bayern

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)


df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)


df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)


frames = [df1, df2, df3]

result = pd.concat(frames)

result = pd.concat(frames, keys=["x", "y", "z"])

# %%
result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
players
# Out:
#         Nationality           Club  World_Champion  Height  Goals_2018
# Player
# Danijel      Serbia      Barcelona           False    1.70          45
# Messi     Argentina       Juventus           False    1.87          44
# Neymar       Brasil       Paris SG            True    1.75          28
# Ivanka       Serbia  Crvena Zvezda            True    1.93          21
# Junior      Germany         Bayern           False    1.84           0

# %%
# players.reset_index(inplace=True)
# players.drop(['level_0'], axis=1, inplace=True)
players
# Out:
#     Player Nationality           Club  World_Champion  Height  Goals_2018
# 0  Danijel      Serbia      Barcelona           False    1.70          45
# 1    Messi   Argentina       Juventus           False    1.87          44
# 2   Neymar      Brasil       Paris SG            True    1.75          28
# 3   Ivanka      Serbia  Crvena Zvezda            True    1.93          21
# 4   Junior     Germany         Bayern           False    1.84           0

# %%
players.loc[5,:] = ['Sergio', 'Spain','Real Madrid',True,1.85,5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 players.loc[5,:] = ['Sergio', 'Spain','Real Madrid',True,1.85,5]
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1688 # align and set the values
#    1689 if take_split_path:
#    1690     # We have to operate column-wise
# -> 1691     self._setitem_with_indexer_split_path(indexer, value, name)
#    1692 else:
#    1693     self._setitem_single_block(indexer, value, name)
#
# ...

# %%
# players.drop(labels=[0], axis=1,inplace=True)
players
# Out:
#     Player Nationality           Club World_Champion  Height  Goals_2018
# 0  Danijel      Serbia      Barcelona          False    1.70        45.0
# 1    Messi   Argentina       Juventus          False    1.87        44.0
# 2   Neymar      Brasil       Paris SG           True    1.75        28.0
# 3   Ivanka      Serbia  Crvena Zvezda           True    1.93        21.0
# 4   Junior     Germany         Bayern          False    1.84         0.0
# 5      NaN         NaN            NaN            NaN     NaN         NaN

# %%
# players.drop(index=5, axis=0,inplace=True)
players
# Out:
#         Nationality           Club World_Champion  Height  Goals_2018
# Player
# Danijel      Serbia      Barcelona          False    1.70        45.0
# Messi     Argentina       Juventus          False    1.87        44.0
# Neymar       Brasil       Paris SG           True    1.75        28.0
# Ivanka       Serbia  Crvena Zvezda           True    1.93        21.0
# Junior      Germany         Bayern          False    1.84         0.0
# 5               NaN            NaN            NaN     NaN         NaN

# %%
players.loc[5,:] = ['Sergio', 'Spain','Real Madrid',True,1.85,5]

# %%
players
# Out:
#         Nationality           Club World_Champion  Height  Goals_2018
# Player
# Danijel      Serbia      Barcelona          False    1.70        45.0
# Messi     Argentina       Juventus          False    1.87        44.0
# Neymar       Brasil       Paris SG           True    1.75        28.0
# Ivanka       Serbia  Crvena Zvezda           True    1.93        21.0
# Junior      Germany         Bayern          False    1.84         0.0
# 5               NaN            NaN            NaN     NaN         NaN

# %% [markdown]
# ## Adding many rows

# %%
new = pd.DataFrame(
data=[['Mohamed', 'Egypt','Liverpool', False,1.67,44],
     ['Luis Suarez', 'Uruguay','Barcelona', False,1.82,32]],
columns=players.columns)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:982, in _finalize_columns_and_data(content, columns, dtype)
#     981 try:
# --> 982     columns = _validate_or_indexify_columns(contents, columns)
#     983 except AssertionError as err:
#     984     # GH#26429 do not raise user-facing AssertionError
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:1030, in _validate_or_indexify_columns(content, columns)
#    1028 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1029     # caller's responsibility to check for this...
# -> 1030     raise AssertionError(
#    1031         f"{len(columns)} columns passed, passed data had "
#    1032         f"{len(content)} columns"
#    1033     )
#    1034 elif is_mi_list:
#    1035
# ...

# %%
new
# Out:
#         Player Nationality       Club  World_Champion  Height  Goals_2018
# 0      Mohamed       Egypt  Liverpool           False    1.67          44
# 1  Luis Suarez     Uruguay  Barcelona           False    1.82          32

# %%
# players = players.append(new,ignore_index=True)
# Out:
# C:\Users\Danijel.Djordjic\AppData\Local\Temp\ipykernel_13528\1382015104.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   players = players.append(new,ignore_index=True)

# %%
players
# Out:
#          Player Nationality           Club World_Champion  Height  Goals_2018
# 0       Danijel      Serbia      Barcelona          False    1.70        45.0
# 1         Messi   Argentina       Juventus          False    1.87        44.0
# 2        Neymar      Brasil       Paris SG           True    1.75        28.0
# 3        Ivanka      Serbia  Crvena Zvezda           True    1.93        21.0
# 4        Junior     Germany         Bayern          False    1.84         0.0
# 5        Sergio       Spain    Real Madrid           True    1.85         5.0
# 6       Mohamed       Egypt      Liverpool          False    1.67        44.0
# 7   Luis Suarez     Uruguay      Barcelona          False    1.82        32.0
# 8       Mohamed       Egypt      Liverpool          False    1.67        44.0
# 9   Luis Suarez     Uruguay      Barcelona          False    1.82        32.0
# 10      Mohamed       Egypt      Liverpool          False    1.67        44.0
# ...

# %%
# players.drop(players.index[8:], inplace=True)

# %%
players
# Out:
#         Player Nationality           Club World_Champion  Height  Goals_2018
# 0      Danijel      Serbia      Barcelona          False    1.70        45.0
# 1        Messi   Argentina       Juventus          False    1.87        44.0
# 2       Neymar      Brasil       Paris SG           True    1.75        28.0
# 3       Ivanka      Serbia  Crvena Zvezda           True    1.93        21.0
# 4       Junior     Germany         Bayern          False    1.84         0.0
# 5       Sergio       Spain    Real Madrid           True    1.85         5.0
# 6      Mohamed       Egypt      Liverpool          False    1.67        44.0
# 7  Luis Suarez     Uruguay      Barcelona          False    1.82        32.0

# %% [markdown]
# ## Adding, joining and concatinating dataframes

# %%
men2004 = pd.read_csv('men2004.csv')
men2008 = pd.read_csv('men2008.csv')

# %%
men2004
# Out:
#                        Athlete  Medals
# 0              PHELPS, Michael       8
# 1                  THORPE, Ian       4
# 2             SCHOEMAN, Roland       3
# 3               PEIRSOL, Aaron       3
# 4                 CROCKER, Ian       3
# 5             KITAJIMA, Kosuke       3
# 6              HANSEN, Brendan       3
# 7   VAN DEN HOOGENBAND, Pieter       3
# 8               HACKETT, Grant       3
# 9               MORITA, Tomomi       2
# 10                LEZAK, Jason       2
# 11               ROGAN, Markus       2
# 12               KELLER, Klete       2
# 13              HALL, Gary Jr.       2
# 14                LOCHTE, Ryan       2
# 15                WALKER, Neil       2
# 16           YAMAMOTO, Takashi       2
# 17          SPRENGER, Nicholas       1
# 18          OKUMURA, Yoshihiro       1
# 19              PARRY, Stephen       1
# 20               PEARSON, Todd       1
# 21              ZASTROW, Mitja       1
# 22          PELLICIARI, Matteo       1
# ...

# %%
men2008
# Out:
#                 Athlete  Medals
# 0       PHELPS, Michael       8
# 1          LOCHTE, Ryan       4
# 2        BERNARD, Alain       3
# 3       SULLIVAN, Eamon       3
# 4   LAUTERSTEIN, Andrew       3
# ..                  ...     ...
# 57     LAGUNOV, Evgeniy       1
# 58        BERENS, Ricky       1
# 59         LURZ, Thomas       1
# 60      MALLET, Gregory       1
# 61           ZHANG, Lin       1
#
# [62 rows x 2 columns]

# %%
men2004.append(men2008, ignore_index=False)
# Out:
# C:\Users\Danijel.Djordjic\AppData\Local\Temp\ipykernel_13528\2574716252.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   men2004.append(men2008, ignore_index=False)
#              Athlete  Medals
# 0    PHELPS, Michael       8
# 1        THORPE, Ian       4
# 2   SCHOEMAN, Roland       3
# 3     PEIRSOL, Aaron       3
# 4       CROCKER, Ian       3
# ..               ...     ...
# 57  LAGUNOV, Evgeniy       1
# 58     BERENS, Ricky       1
# 59      LURZ, Thomas       1
# 60   MALLET, Gregory       1
# 61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
pd.concat([men2004,men2008], ignore_index=False, axis=0)
# Out:
#              Athlete  Medals
# 0    PHELPS, Michael       8
# 1        THORPE, Ian       4
# 2   SCHOEMAN, Roland       3
# 3     PEIRSOL, Aaron       3
# 4       CROCKER, Ian       3
# ..               ...     ...
# 57  LAGUNOV, Evgeniy       1
# 58     BERENS, Ricky       1
# 59      LURZ, Thomas       1
# 60   MALLET, Gregory       1
# 61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
summer['Athlete'].str.contains('Milorad').sum()
# Out:
# 6

# %%
summer[summer['Athlete'].str.contains('Milorad')]
# Out:
#        Year         City     Sport  Discipline              Athlete Country  \
# 13492  1972       Munich  Handball    Handball     KARALIC, Milorad     YUG
# 15355  1980       Moscow  Aquatics  Water polo  KRIVOKAPIC, Milorad     YUG
# 16222  1980       Moscow    Rowing      Rowing    STANULOV, Milorad     YUG
# 16762  1984  Los Angeles  Aquatics  Water polo  KRIVOKAPIC, Milorad     YUG
# 17662  1984  Los Angeles    Rowing      Rowing    STANULOV, Milorad     YUG
# 27225  2008      Beijing  Aquatics    Swimming       CAVIC, Milorad     SRB
#
#       Gender               Event   Medal
# 13492    Men            Handball    Gold
# 15355    Men          Water Polo  Silver
# 16222    Men  Double Sculls (2X)  Silver
# 16762    Men          Water Polo    Gold
# 17662    Men  Double Sculls (2X)  Bronze
# 27225    Men      100M Butterfly  Silver

# %%
pd.concat([men2004,men2008], ignore_index=False, axis=0, keys=[2004,2008])
# Out:
#                   Athlete  Medals
# 2004 0    PHELPS, Michael       8
#      1        THORPE, Ian       4
#      2   SCHOEMAN, Roland       3
#      3     PEIRSOL, Aaron       3
#      4       CROCKER, Ian       3
# ...                   ...     ...
# 2008 57  LAGUNOV, Evgeniy       1
#      58     BERENS, Ricky       1
#      59      LURZ, Thomas       1
#      60   MALLET, Gregory       1
#      61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men_0408 = pd.concat([men2004,men2008], ignore_index=False, axis=0, keys=[2004,2008], names=['Year'])

# %%
men_0408
# Out:
#                   Athlete  Medals
# Year
# 2004 0    PHELPS, Michael       8
#      1        THORPE, Ian       4
#      2   SCHOEMAN, Roland       3
#      3     PEIRSOL, Aaron       3
#      4       CROCKER, Ian       3
# ...                   ...     ...
# 2008 57  LAGUNOV, Evgeniy       1
#      58     BERENS, Ricky       1
#      59      LURZ, Thomas       1
#      60   MALLET, Gregory       1
#      61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men_0408.reset_index()
# Out:
#      Year  level_1           Athlete  Medals
# 0    2004        0   PHELPS, Michael       8
# 1    2004        1       THORPE, Ian       4
# 2    2004        2  SCHOEMAN, Roland       3
# 3    2004        3    PEIRSOL, Aaron       3
# 4    2004        4      CROCKER, Ian       3
# ..    ...      ...               ...     ...
# 116  2008       57  LAGUNOV, Evgeniy       1
# 117  2008       58     BERENS, Ricky       1
# 118  2008       59      LURZ, Thomas       1
# 119  2008       60   MALLET, Gregory       1
# 120  2008       61        ZHANG, Lin       1
#
# [121 rows x 4 columns]

# %%
men_0408.drop(columns= 'level_1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [180], in <cell line: 1>()
# ----> 1 men_0408.drop(columns= 'level_1')
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
# ...

# %%
men_0408
# Out:
#                   Athlete  Medals
# Year
# 2004 0    PHELPS, Michael       8
#      1        THORPE, Ian       4
#      2   SCHOEMAN, Roland       3
#      3     PEIRSOL, Aaron       3
#      4       CROCKER, Ian       3
# ...                   ...     ...
# 2008 57  LAGUNOV, Evgeniy       1
#      58     BERENS, Ricky       1
#      59      LURZ, Thomas       1
#      60   MALLET, Gregory       1
#      61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men_0408.reset_index().drop(columns='level_1')
# Out:
#      Year           Athlete  Medals
# 0    2004   PHELPS, Michael       8
# 1    2004       THORPE, Ian       4
# 2    2004  SCHOEMAN, Roland       3
# 3    2004    PEIRSOL, Aaron       3
# 4    2004      CROCKER, Ian       3
# ..    ...               ...     ...
# 116  2008  LAGUNOV, Evgeniy       1
# 117  2008     BERENS, Ricky       1
# 118  2008      LURZ, Thomas       1
# 119  2008   MALLET, Gregory       1
# 120  2008        ZHANG, Lin       1
#
# [121 rows x 3 columns]

# %% [markdown]
# ## Manipulating elements in DataFrame

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.loc[1, 'age'] = 40
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  40.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.iloc[1,3] = 41
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  41.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.loc[1:3, 'age'] = 43
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  43.0      1      0  71.2833        C    C
# 2           1       3  female  43.0      0      0   7.9250        S  NaN
# 3           1       1  female  43.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.loc[:, 'age']  = titanic.loc[:,'age'] * 12
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked deck
# 0           0       3    male  264.0      1      0   7.2500        S  NaN
# 1           1       1  female  516.0      1      0  71.2833        C    C
# 2           1       3  female  516.0      0      0   7.9250        S  NaN
# 3           1       1  female  516.0      1      0  53.1000        S    C
# 4           0       3    male  420.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...    ...    ...    ...      ...      ...  ...
# 886         0       2    male  324.0      0      0  13.0000        S  NaN
# 887         1       1  female  228.0      0      0  30.0000        S    B
# 888         0       3  female    NaN      1      2  23.4500        S  NaN
# 889         1       1    male  312.0      0      0  30.0000        C    C
# 890         0       3    male  384.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.loc[:, 'age']  = titanic.loc[:,'age'] / 12
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  43.0      1      0  71.2833        C    C
# 2           1       3  female  43.0      0      0   7.9250        S  NaN
# 3           1       1  female  43.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
index_babies = titanic.loc[titanic.age < 1].index
index_babies
# Out:
# Int64Index([78, 305, 469, 644, 755, 803, 831], dtype='int64')

# %%
titanic.loc[index_babies]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  0.83      0      2   29.0000        S  NaN
# 305         1       1    male  0.92      1      2  151.5500        S    C
# 469         1       3  female  0.75      2      1   19.2583        C  NaN
# 644         1       3  female  0.75      2      1   19.2583        C  NaN
# 755         1       2    male  0.67      1      1   14.5000        S  NaN
# 803         1       3    male  0.42      0      1    8.5167        C  NaN
# 831         1       2    male  0.83      1      1   18.7500        S  NaN

# %%
titanic.loc[titanic.age < 1, 'age'] = 1
titanic.loc[index_babies]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %%
titanic.sex.dtypes
# Out:
# dtype('O')

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic_slice = titanic.iloc[:10, [2,3]]
titanic_slice
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0
# 5    male   NaN
# 6    male  54.0
# 7    male   2.0
# 8  female  27.0
# 9  female  14.0

# %%
titanic_slice.groupby('age').mean()
# Out:
# C:\Users\Danijel.Djordjic\AppData\Local\Temp\ipykernel_1792\3109953367.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   titanic_slice.groupby('age').mean()
# Empty DataFrame
# Columns: []
# Index: [2.0, 14.0, 22.0, 26.0, 27.0, 35.0, 38.0, 54.0]

# %%
gbo = titanic_slice.groupby('sex')

# %%
l = list(gbo)
l
# Out:
# [('female',
#         sex   age
#   1  female  38.0
#   2  female  26.0
#   3  female  35.0
#   8  female  27.0
#   9  female  14.0),
#  ('male',
#       sex   age
#   0  male  22.0
#   4  male  35.0
#   5  male   NaN
#   6  male  54.0
#   7  male   2.0)]

# %%
l[0][0]
# Out:
# 'female'

# %%
sliced_f = l[0][1]
sliced_f
# Out:
#       sex   age
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 8  female  27.0
# 9  female  14.0

# %%
sliced_m = l[1][1]
sliced_m
# Out:
#     sex   age
# 0  male  22.0
# 4  male  35.0
# 5  male   NaN
# 6  male  54.0
# 7  male   2.0

# %%
male_female_df = pd.concat()
male_female_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [120], in <cell line: 1>()
# ----> 1 male_female_df = pd.concat()
#       2 male_female_df
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: concat() missing 1 required positional argument: 'objs'

# %%
pd.concat([sliced_f,sliced_m],sort=True )
# Out:
#     age     sex
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 8  27.0  female
# 9  14.0  female
# 0  22.0    male
# 4  35.0    male
# 5   NaN    male
# 6  54.0    male
# 7   2.0    male
